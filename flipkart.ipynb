# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshuguru/-DATA-Ground-/blob/main/flipkart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("/content/Flipkart.csv")
df
# Out:
#        Brand      Model            Color  ... Rating Selling Price  Original Price
# 0       OPPO        A53  Moonlight Black  ...    4.5       11990.0         15990.0
# 1       OPPO        A53       Mint Cream  ...    4.5       11990.0         15990.0
# 2       OPPO        A53  Moonlight Black  ...    4.3       13990.0         17990.0
# 3       OPPO        A53       Mint Cream  ...    4.3       13990.0         17990.0
# 4       OPPO        A53   Electric Black  ...    4.5       11990.0         15990.0
# ...      ...        ...              ...  ...    ...           ...             ...
# 2642  Xiaomi  Redmi Y3          Bold Red  ...    4.3       12999.0         13999.0
# 2643  Xiaomi  Redmi Y3      Elegant Blue  ...    4.3        9450.0             NaN
# 2644  Xiaomi  Redmi Y3      Elegant Blue  ...    4.2       12999.0             NaN
# 2645  Xiaomi  Redmi Y3       Prime Black  ...    4.2        9950.0             NaN
# ...

# %%
df.shape
# Out:
# (2647, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2647 entries, 0 to 2646
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           2647 non-null   object
#  1   Model           2645 non-null   object
#  2   Color           2505 non-null   object
#  3   Memory          2605 non-null   object
#  4   Storage         2568 non-null   object
#  5   Rating          2647 non-null   float64
#  6   Selling Price   2644 non-null   float64
#  7   Original Price  969 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 165.6+ KB

# %%
df.describe()
# Out:
#             Rating  Selling Price  Original Price
# count  2647.000000    2644.000000      969.000000
# mean      4.001700   26461.362330    29852.605779
# std       0.997499   29833.135164    27659.141051
# min       0.000000    1000.000000     1599.000000
# 25%       4.000000    9490.000000    12999.000000
# 50%       4.300000   14999.000000    18999.000000
# 75%       4.400000   29998.250000    34999.000000
# max       5.000000  179900.000000   189999.000000

# %%
#to know the column names
df.columns
# Out:
# Index(['Brand', 'Model', 'Color', 'Memory', 'Storage', 'Rating',
#        'Selling Price', 'Original Price'],
#       dtype='object')

# %%
#to find the number of null values
df.isnull().sum()
# Out:
# Brand                0
# Model                2
# Color              142
# Memory              42
# Storage             79
# Rating               0
# Selling Price        3
# Original Price    1678
# dtype: int64

# %%
#clearing null values of model column

#to view the rows of nan values of model column
df[df['Model'].isnull()]

#to find the max sold model of Google pixel
a=df[df['Brand']=='Google Pixel']
a.describe(include='object')
#df['Model'].replace(to_replace=0,value='A53')

#to fill 
df['Model'] = df['Model'].fillna('3 XL')

#checking whether the model name is replaces with the max sold model
df[df['Model']=='3 XL']
# Out:
#             Brand Model        Color  ... Rating Selling Price  Original Price
# 274  Google Pixel  3 XL  Quite Black  ...    4.4       66000.0             NaN
# 275  Google Pixel  3 XL  Very Silver  ...    4.4       57000.0             NaN
#
# [2 rows x 8 columns]

# %%
df[df['Model'].isnull()]
# Out:
#             Brand Model        Color  ... Rating Selling Price  Original Price
# 274  Google Pixel   NaN  Quite Black  ...    4.4       66000.0             NaN
# 275  Google Pixel   NaN  Very Silver  ...    4.4       57000.0             NaN
#
# [2 rows x 8 columns]

# %%
df[df['Brand']=='Google Pixel']
# Out:
#             Brand      Model  ... Selling Price Original Price
# 254  Google Pixel        4a   ...       31999.0            NaN
# 255  Google Pixel     3a XL   ...       44999.0            NaN
# 256  Google Pixel          3  ...       69999.0            NaN
# 257  Google Pixel     3a XL   ...       44999.0            NaN
# 258  Google Pixel          3  ...       71000.0            NaN
# 259  Google Pixel          3  ...       71000.0            NaN
# 260  Google Pixel          3  ...       80000.0            NaN
# 261  Google Pixel      3 XL   ...       83000.0            NaN
# 262  Google Pixel      3 XL   ...       83000.0            NaN
# 263  Google Pixel      3 XL   ...       92000.0            NaN
# 264  Google Pixel          3  ...       80000.0            NaN
# 265  Google Pixel          3  ...       80000.0            NaN
# 266  Google Pixel      3 XL   ...       92000.0            NaN
# 267  Google Pixel      3 XL   ...       83000.0            NaN
# ...

# %%
df[df['Selling Price'].isnull()]
# Out:
#      Brand            Model  ... Selling Price Original Price
# 128   OPPO              A16  ...           NaN            NaN
# 420   ASUS  Zenfone Go 5.0   ...           NaN            NaN
# 2426  vivo            Y20G   ...           NaN            NaN
#
# [3 rows x 8 columns]

# %%
# the cosidered model isn't accepted to return the df     --->> doubt
df[(df['Brand']=='ASUS')&(df['Model']=='Zenfone Go 5.0')]
# Out:
# Empty DataFrame
# Columns: [Brand, Model, Color, Memory, Storage, Rating, Selling Price, Original Price]
# Index: []

# %%
df[(df['Brand']=='OPPO')&(df['Model']=='A16')]
df[(df['Color']=='Obsidian Black')&(df['Brand']=='vivo')]
df[(df['Brand']=='ASUS')&(df['Color']=='Black')]
# Out:
#     Brand                        Model  ... Selling Price Original Price
# 382  ASUS                 ROG Phone 5   ...       49999.0        55999.0
# 383  ASUS                 ROG Phone 3   ...       49999.0        57999.0
# 385  ASUS     Zenfone 2 Laser ZE500KL   ...        7999.0            NaN
# 386  ASUS                 ROG Phone 3   ...       46999.0        55999.0
# 390  ASUS                          6Z   ...       35999.0            NaN
# 391  ASUS          Zenfone Max Pro M1   ...       15599.0            NaN
# 392  ASUS              Zenfone Go 4.5   ...        5299.0            NaN
# 393  ASUS              ZenFone Max M2   ...       14999.0            NaN
# 400  ASUS             ZenFone Lite L1   ...        7199.0            NaN
# 401  ASUS              ZenFone Max M2   ...       12999.0            NaN
# 402  ASUS            Zenfone 4 Selfie   ...       10999.0            NaN
# 406  ASUS                ROG Phone II   ...       40999.0            NaN
# ...

# %%
# to clear the nan values of selling price column

#to know the rows with nan
df[df['Selling Price'].isnull()]

#finding similarity
df[(df['Brand']=='OPPO')&(df['Model']=='A16')]
df[(df['Color']=='Obsidian Black')&(df['Brand']=='vivo')]
df[(df['Brand']=='ASUS')&(df['Color']=='Black')]


#with the above result we'll get the similare datas. hence substituition
df.loc[128,'Selling Price'] = 13990.0
df.loc[2426,'Selling Price'] = 23990.0	
df.loc[420,'Selling Price'] = 4499.0	

#  df.at[df['absences'].argmax(), 'famsize']    --->> this can be used to replace the multiple nan values 
#which is used to automate the index values

# %%
df.isnull().sum()
# Out:
# Brand                0
# Model                0
# Color              142
# Memory              42
# Storage             79
# Rating               0
# Selling Price        0
# Original Price    1678
# dtype: int64

# %%
# saving the reduced errors file as a file
df.to_csv('reduced error_Flipkart.csv',index=False)
df_1=pd.read_csv('/content/reduced error_Flipkart.csv')
df_1
# Out:
#        Brand      Model            Color  ... Rating Selling Price  Original Price
# 0       OPPO        A53  Moonlight Black  ...    4.5       11990.0         15990.0
# 1       OPPO        A53       Mint Cream  ...    4.5       11990.0         15990.0
# 2       OPPO        A53  Moonlight Black  ...    4.3       13990.0         17990.0
# 3       OPPO        A53       Mint Cream  ...    4.3       13990.0         17990.0
# 4       OPPO        A53   Electric Black  ...    4.5       11990.0         15990.0
# ...      ...        ...              ...  ...    ...           ...             ...
# 2642  Xiaomi  Redmi Y3          Bold Red  ...    4.3       12999.0         13999.0
# 2643  Xiaomi  Redmi Y3      Elegant Blue  ...    4.3        9450.0             NaN
# 2644  Xiaomi  Redmi Y3      Elegant Blue  ...    4.2       12999.0             NaN
# 2645  Xiaomi  Redmi Y3       Prime Black  ...    4.2        9950.0             NaN
# ...

# %%
df_1=pd.read_csv('/content/reduced error_Flipkart.csv')
df_1
# Out:
#        Brand      Model            Color  ... Rating Selling Price  Original Price
# 0       OPPO        A53  Moonlight Black  ...    4.5       11990.0         15990.0
# 1       OPPO        A53       Mint Cream  ...    4.5       11990.0         15990.0
# 2       OPPO        A53  Moonlight Black  ...    4.3       13990.0         17990.0
# 3       OPPO        A53       Mint Cream  ...    4.3       13990.0         17990.0
# 4       OPPO        A53   Electric Black  ...    4.5       11990.0         15990.0
# ...      ...        ...              ...  ...    ...           ...             ...
# 2642  Xiaomi  Redmi Y3          Bold Red  ...    4.3       12999.0         13999.0
# 2643  Xiaomi  Redmi Y3      Elegant Blue  ...    4.3        9450.0             NaN
# 2644  Xiaomi  Redmi Y3      Elegant Blue  ...    4.2       12999.0             NaN
# 2645  Xiaomi  Redmi Y3       Prime Black  ...    4.2        9950.0             NaN
# ...

# %%
df[(df['Model']=='106')|(df['Model']=='225')]
# Out:
#       Brand Model Color  ... Rating Selling Price  Original Price
# 997   Nokia   106   NaN  ...    3.9        1400.0             NaN
# 1026  Nokia   225   NaN  ...    4.0        3499.0             NaN
# 1029  Nokia   106   NaN  ...    4.2        1560.0             NaN
# 1074  Nokia   106   NaN  ...    3.9        1519.0             NaN
# 1095  Nokia   225   NaN  ...    3.6        3499.0             NaN
# 1096  Nokia   225   NaN  ...    3.6        3499.0             NaN
#
# [6 rows x 8 columns]

# %%
df[df['Memory'].isnull()]
# Out:
#         Brand                    Model  ... Selling Price Original Price
# 997     Nokia                      106  ...        1400.0            NaN
# 1074    Nokia                      106  ...        1519.0            NaN
# 1095    Nokia                      225  ...        3499.0            NaN
# 1096    Nokia                      225  ...        3499.0            NaN
# 1166    Apple       iPhone 12 Pro Max   ...      149900.0            NaN
# 1207    Apple       iPhone 12 Pro Max   ...      149900.0            NaN
# 1208    Apple       iPhone 12 Pro Max   ...      149900.0            NaN
# 1215    Apple       iPhone 12 Pro Max   ...      149900.0            NaN
# 1219    Apple       iPhone 12 Pro Max   ...      129900.0            NaN
# 1228    Apple       iPhone 12 Pro Max   ...      129900.0            NaN
# 1235    Apple       iPhone 12 Pro Max   ...      119900.0            NaN
# 1237    Apple       iPhone 12 Pro Max   ...      119900.0            NaN
# ...

# %%
# there are 16 unique brand in this dataset                       --->>   NOKIA
# to replace the nan values to the memory column 

# wrt price alone since the storage coln corresponding to that has the nan values
df.loc[997,'Memory'] =  '4 MB'	
df.loc[1074,'Memory'] = '4 MB'

# wrt storage|price, coz both the colns has the data.
df.loc[1095,'Memory']='8 MB'
df.loc[1096,'Memory']='8 MB'

# %%
df.isnull().sum()
# Out:
# Brand                0
# Model                0
# Color              142
# Memory              38
# Storage             79
# Rating               0
# Selling Price        0
# Original Price    1678
# dtype: int64

# %%
df['Brand'].nunique()
# Out:
# 16

# %%
df['Memory'].replace(np.NaN,0)
# Out:
# 0       4 GB
# 1       4 GB
# 2       6 GB
# 3       6 GB
# 4       4 GB
#         ...
# 2642    4 GB
# 2643    3 GB
# 2644    4 GB
# 2645    3 GB
# 2646    4 GB
# Name: Memory, Length: 2647, dtype: object

# %%
df2=df[(df['Memory']==6)&(df['Brand']=='Apple')]
df2
# Out:
#       Brand               Model  ... Selling Price Original Price
# 1166  Apple  iPhone 12 Pro Max   ...      149900.0            NaN
# 1207  Apple  iPhone 12 Pro Max   ...      149900.0            NaN
# 1208  Apple  iPhone 12 Pro Max   ...      149900.0            NaN
# 1215  Apple  iPhone 12 Pro Max   ...      149900.0            NaN
# 1219  Apple  iPhone 12 Pro Max   ...      129900.0            NaN
# 1228  Apple  iPhone 12 Pro Max   ...      129900.0            NaN
# 1235  Apple  iPhone 12 Pro Max   ...      119900.0            NaN
# 1237  Apple  iPhone 12 Pro Max   ...      119900.0            NaN
# 1240  Apple  iPhone 12 Pro Max   ...      119900.0            NaN
# 1298  Apple  iPhone 12 Pro Max   ...      129900.0            NaN
# 1299  Apple  iPhone 12 Pro Max   ...      119900.0            NaN
# 1469  Apple           iPhone 7   ...       74400.0            NaN
# 1474  Apple  iPhone 12 Pro Max   ...      129900.0            NaN
#
# [13 rows x 8 columns]

# %%
df[(df['Storage']=='256 GB')&(df['Brand']=='Apple')]
# Out:
#       Brand               Model  ... Selling Price Original Price
# 1128  Apple      iPhone 13 Pro   ...      129900.0            NaN
# 1135  Apple          iPhone 12   ...       78999.0        80900.0
# 1140  Apple          iPhone 12   ...       78999.0        80900.0
# 1146  Apple          iPhone 13   ...       89900.0            NaN
# 1152  Apple          iPhone SE   ...       54900.0            NaN
# ...     ...                 ...  ...           ...            ...
# 1465  Apple           iPhone 7   ...       74400.0            NaN
# 1469  Apple           iPhone 7   ...       74400.0            NaN
# 1474  Apple  iPhone 12 Pro Max   ...      129900.0            NaN
# 1475  Apple           iPhone X   ...      106900.0            NaN
# 1478  Apple          iPhone 11   ...       64900.0            NaN
#
# [103 rows x 8 columns]

# %%
df[df[(df['Brand']=='Apple') &(df['Memory'].isnull())]
# Out:
#   File "<ipython-input-74-306b0444a9c4>", line 1
#     df[df[(df['Brand']=='Apple') &(df['Memory'].isnull())]
#                                                           ^
# SyntaxError: unexpected EOF while parsing

# %%
for index, row in df2.iterrows():
 if (df['Brand']=='Apple') and (df['Memory'].isnull()):
   df.loc[index,df['Memory']]=='value'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-3b21f7fd953c> in <module>()
#       1 for index, row in df.iterrows():
# ----> 2  if (df['Brand']=='Apple') and (df['Memory'].isnull()):
#       3     df.replace(np.NaN,'6 GB')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1328     def __nonzero__(self):
#    1329         raise ValueError(
# -> 1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1332         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df2
# Out:
#       Brand               Model  ... Selling Price Original Price
# 1166  Apple  iPhone 12 Pro Max   ...      149900.0            NaN
# 1207  Apple  iPhone 12 Pro Max   ...      149900.0            NaN
# 1208  Apple  iPhone 12 Pro Max   ...      149900.0            NaN
# 1215  Apple  iPhone 12 Pro Max   ...      149900.0            NaN
# 1219  Apple  iPhone 12 Pro Max   ...      129900.0            NaN
# 1228  Apple  iPhone 12 Pro Max   ...      129900.0            NaN
# 1235  Apple  iPhone 12 Pro Max   ...      119900.0            NaN
# 1237  Apple  iPhone 12 Pro Max   ...      119900.0            NaN
# 1240  Apple  iPhone 12 Pro Max   ...      119900.0            NaN
# 1298  Apple  iPhone 12 Pro Max   ...      129900.0            NaN
# 1299  Apple  iPhone 12 Pro Max   ...      119900.0            NaN
# 1469  Apple           iPhone 7   ...       74400.0            NaN
# 1474  Apple  iPhone 12 Pro Max   ...      129900.0            NaN
#
# [13 rows x 8 columns]

# %%
df['Memory']=df['Memory'].fillna(6)

# %% [markdown]
# df[(df['Brand']=='Apple')]#(df['Memory']==6)]
